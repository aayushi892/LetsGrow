# %%
import  pandas as pd
import numpy as np

# %%
df=pd.read_csv("Iris-f.csv")
df.head()
# Out:
#    SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species
# 0            5.1           3.5            1.4           0.2  Iris-setosa
# 1            4.9           3.0            1.4           0.2  Iris-setosa
# 2            4.7           3.2            1.3           0.2  Iris-setosa
# 3            4.6           3.1            1.5           0.2  Iris-setosa
# 4            NaN           3.6            1.4           0.2  Iris-setosa

# %%
df.isna().sum()
# Out:
# SepalLengthCm    2
# SepalWidthCm     1
# PetalLengthCm    1
# PetalWidthCm     0
# Species          1
# dtype: int64

# %%
df[df.isna().any(axis=1)].index
# Out:
# Int64Index([4, 7, 10, 20], dtype='int64')

# %% [markdown]
# Removing of rows and columns

# %%
df1 = df.copy(deep=True)

# %%
df1.dropna(axis=0,inplace=True)

# %%
df1.isna().sum()
# Out:
# SepalLengthCm    0
# SepalWidthCm     0
# PetalLengthCm    0
# PetalWidthCm     0
# Species          0
# dtype: int64

# %%
df1.shape
# Out:
# (146, 5)

# %%
df1.head()
# Out:
#    SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species
# 0            5.1           3.5            1.4           0.2  Iris-setosa
# 1            4.9           3.0            1.4           0.2  Iris-setosa
# 2            4.7           3.2            1.3           0.2  Iris-setosa
# 3            4.6           3.1            1.5           0.2  Iris-setosa
# 5            5.4           3.9            1.7           0.4  Iris-setosa

# %%
df1.dropna(axis=0,inplace=True,thresh=4)

# %%
df1.head()
# Out:
#    SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species
# 0            5.1           3.5            1.4           0.2  Iris-setosa
# 1            4.9           3.0            1.4           0.2  Iris-setosa
# 2            4.7           3.2            1.3           0.2  Iris-setosa
# 3            4.6           3.1            1.5           0.2  Iris-setosa
# 5            5.4           3.9            1.7           0.4  Iris-setosa

# %%
df2 = df.copy(deep=True)

# %%
df2.fillna(0)
# Out:
#      SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm         Species
# 0              5.1           3.5            1.4           0.2     Iris-setosa
# 1              4.9           3.0            1.4           0.2     Iris-setosa
# 2              4.7           3.2            1.3           0.2     Iris-setosa
# 3              4.6           3.1            1.5           0.2     Iris-setosa
# 4              0.0           3.6            1.4           0.2     Iris-setosa
# ..             ...           ...            ...           ...             ...
# 145            6.7           3.0            5.2           2.3  Iris-virginica
# 146            6.3           2.5            5.0           1.9  Iris-virginica
# 147            6.5           3.0            5.2           2.0  Iris-virginica
# 148            6.2           3.4            5.4           2.3  Iris-virginica
# 149            5.9           3.0            5.1           1.8  Iris-virginica
#
# [150 rows x 5 columns]

# %%
df2.head()
# Out:
#    SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species
# 0            5.1           3.5            1.4           0.2  Iris-setosa
# 1            4.9           3.0            1.4           0.2  Iris-setosa
# 2            4.7           3.2            1.3           0.2  Iris-setosa
# 3            4.6           3.1            1.5           0.2  Iris-setosa
# 4            NaN           3.6            1.4           0.2  Iris-setosa

# %%
df2.iloc[[4,7,10,20],:]
# Out:
#     SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species
# 4             NaN           3.6            1.4           0.2  Iris-setosa
# 7             5.0           NaN            NaN           0.2  Iris-setosa
# 10            5.4           3.7            1.5           0.2          NaN
# 20            NaN           3.4            1.7           0.2  Iris-setosa

# %%
###df2.fillna(0,inplace=True)
df2.head()
# Out:
#    SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species
# 0            5.1           3.5            1.4           0.2  Iris-setosa
# 1            4.9           3.0            1.4           0.2  Iris-setosa
# 2            4.7           3.2            1.3           0.2  Iris-setosa
# 3            4.6           3.1            1.5           0.2  Iris-setosa
# 4            NaN           3.6            1.4           0.2  Iris-setosa

# %% [markdown]
# ##

# %%
df2.mean()
# Out:
# C:\Users\aayushi sinha\AppData\Local\Temp\ipykernel_8164\3587575296.py:1: FutureWarning: The default value of numeric_only in DataFrame.mean is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   df2.mean()
# SepalLengthCm    5.852027
# SepalWidthCm     3.051678
# PetalLengthCm    3.773826
# PetalWidthCm     1.198667
# dtype: float64

# %%
df2.fillna(df2.mean(),inplace=True)
# Out:
# C:\Users\aayushi sinha\AppData\Local\Temp\ipykernel_8164\1812428121.py:1: FutureWarning: The default value of numeric_only in DataFrame.mean is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   df2.fillna(df2.mean(),inplace=True)

# %%
df2
# Out:
#      SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm         Species
# 0         5.100000           3.5            1.4           0.2     Iris-setosa
# 1         4.900000           3.0            1.4           0.2     Iris-setosa
# 2         4.700000           3.2            1.3           0.2     Iris-setosa
# 3         4.600000           3.1            1.5           0.2     Iris-setosa
# 4         5.852027           3.6            1.4           0.2     Iris-setosa
# ..             ...           ...            ...           ...             ...
# 145       6.700000           3.0            5.2           2.3  Iris-virginica
# 146       6.300000           2.5            5.0           1.9  Iris-virginica
# 147       6.500000           3.0            5.2           2.0  Iris-virginica
# 148       6.200000           3.4            5.4           2.3  Iris-virginica
# 149       5.900000           3.0            5.1           1.8  Iris-virginica
#
# [150 rows x 5 columns]

# %%
df2['Species'].fillna(df2['Species'].mode(),inplace=True)

# %%
df2.head()
# Out:
#    SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species
# 0       5.100000           3.5            1.4           0.2  Iris-setosa
# 1       4.900000           3.0            1.4           0.2  Iris-setosa
# 2       4.700000           3.2            1.3           0.2  Iris-setosa
# 3       4.600000           3.1            1.5           0.2  Iris-setosa
# 4       5.852027           3.6            1.4           0.2  Iris-setosa

# %%
df2.fillna(method="bfill")
df2.head(10)
# Out:
#    SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species
# 0       5.100000      3.500000       1.400000           0.2  Iris-setosa
# 1       4.900000      3.000000       1.400000           0.2  Iris-setosa
# 2       4.700000      3.200000       1.300000           0.2  Iris-setosa
# 3       4.600000      3.100000       1.500000           0.2  Iris-setosa
# 4       5.852027      3.600000       1.400000           0.2  Iris-setosa
# 5       5.400000      3.900000       1.700000           0.4  Iris-setosa
# 6       4.600000      3.400000       1.400000           0.3  Iris-setosa
# 7       5.000000      3.051678       3.773826           0.2  Iris-setosa
# 8       4.400000      2.900000       1.400000           0.2  Iris-setosa
# 9       4.900000      3.100000       1.500000           0.1  Iris-setosa

# %%
from sklearn.impute import SimpleImputer

# %%
si=SimpleImputer()

# %%
si.fit_transform(df2)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[39], line 1
# ----> 1 si.fit_transform(df2)
#
# File D:\Users\aayushi sinha\anaconda3\lib\site-packages\sklearn\utils\_set_output.py:142, in _wrap_method_output.<locals>.wrapped(self, X, *args, **kwargs)
#     140 @wraps(f)
#     141 def wrapped(self, X, *args, **kwargs):
# --> 142     data_to_wrap = f(self, X, *args, **kwargs)
#     143     if isinstance(data_to_wrap, tuple):
#     144         # only wrap the first output for cross decomposition
#     145         return (
#     146             _wrap_data_with_container(method, data_to_wrap[0], X, self),
#     147             *data_to_wrap[1:],
#     148         )
#
# File D:\Users\aayushi sinha\anaconda3\lib\site-packages\sklearn\base.py:859, in TransformerMixin.fit_transform(self, X, y, **fit_params)
# ...

# %%
df3=df.copy(deep=True)
si.fit_transform(df3.iloc[:,0:4])
# Out:
# array([[5.1       , 3.5       , 1.4       , 0.2       ],
#        [4.9       , 3.        , 1.4       , 0.2       ],
#        [4.7       , 3.2       , 1.3       , 0.2       ],
#        [4.6       , 3.1       , 1.5       , 0.2       ],
#        [5.85202703, 3.6       , 1.4       , 0.2       ],
#        [5.4       , 3.9       , 1.7       , 0.4       ],
#        [4.6       , 3.4       , 1.4       , 0.3       ],
#        [5.        , 3.05167785, 3.7738255 , 0.2       ],
#        [4.4       , 2.9       , 1.4       , 0.2       ],
#        [4.9       , 3.1       , 1.5       , 0.1       ],
#        [5.4       , 3.7       , 1.5       , 0.2       ],
#        [4.8       , 3.4       , 1.6       , 0.2       ],
#        [4.8       , 3.        , 1.4       , 0.1       ],
#        [4.3       , 3.        , 1.1       , 0.1       ],
#        [5.8       , 4.        , 1.2       , 0.2       ],
#        [5.7       , 4.4       , 1.5       , 0.4       ],
# ...

# %%
si1=SimpleImputer(strategy="most_frequent")

# %%
si1.fit_transform(df[['Species']])
# Out:
# array([['Iris-setosa'],
#        ['Iris-setosa'],
#        ['Iris-setosa'],
#        ['Iris-setosa'],
#        ['Iris-setosa'],
#        ['Iris-setosa'],
#        ['Iris-setosa'],
#        ['Iris-setosa'],
#        ['Iris-setosa'],
#        ['Iris-setosa'],
#        ['Iris-versicolor'],
#        ['Iris-setosa'],
#        ['Iris-setosa'],
#        ['Iris-setosa'],
#        ['Iris-setosa'],
#        ['Iris-setosa'],
#        ['Iris-setosa'],
#        ['Iris-setosa'],
#        ['Iris-setosa'],
#        ['Iris-setosa'],
#        ['Iris-setosa'],
#        ['Iris-setosa'],
#        ['Iris-setosa'],
#        ['Iris-setosa'],
#        ['Iris-setosa'],
#        ['Iris-setosa'],
#        ['Iris-setosa'],
#        ['Iris-setosa'],
#        ['Iris-setosa'],
#        ['Iris-setosa'],
#        ['Iris-setosa'],
#        ['Iris-setosa'],
#        ['Iris-setosa'],
#        ['Iris-setosa'],
#        ['Iris-setosa'],
#        ['Iris-setosa'],
#        ['Iris-setosa'],
#        ['Iris-setosa'],
# ...

# %%
df5=df.iloc[:,0:4]
from sklearn.preprocessing import MinMaxScaler
mm=MinMaxScaler()
ans=mm.fit_transform(df5)
